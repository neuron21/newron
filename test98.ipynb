# %%
# !git clone https://github.com/ultralytics/ultralytics
# %cd ultralytics
# !pip install -r requirements.txt
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 11455, done.
# remote: Counting objects: 100% (699/699), done.
# remote: Compressing objects: 100% (339/339), done.
# remote: Total 11455 (delta 426), reused 559 (delta 353), pack-reused 10756
# Receiving objects: 100% (11455/11455), 7.38 MiB | 8.72 MiB/s, done.
# Resolving deltas: 100% (7595/7595), done.
# /content/ultralytics
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8s.pt")
# Out:
# ...
# 100%|██████████| 21.5M/21.5M [00:00<00:00, 45.3MB/s]

# %%
# !git clone https://github.com/neuron21/newron
# Out:
# Cloning into 'newron'...
# remote: Enumerating objects: 416, done.
# remote: Counting objects: 100% (99/99), done.
# remote: Compressing objects: 100% (59/59), done.
# ^C

# %%
results = model.train(data="/content/ultralytics/newron/donuts/donuts.yaml", epochs=300, batch=2, imgsz=1280, rect=True)
results = model.val()
# Out:
# Ultralytics YOLOv8.0.124 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
#学習結果の確認
model = YOLO("/content/ultralytics/best.pt")
results = model.predict(source="/content/ultralytics/IMG_1781.JPG", data="/content/ultralytics/newron/donuts/donuts.yaml", save=True, imgsz=1280, rect=True,conf=0.75)
# Out:
# image 1/1 /content/ultralytics/IMG_1781.JPG: 1280x960 2 pondes, 1 old, 37.5ms
# Speed: 7.5ms preprocess, 37.5ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 960)
# Results saved to /content/ultralytics/runs/detect/predict13

# %%
from IPython.core.debugger import OldPdb
from collections import Counter

counter = Counter(str(results[0].boxes.cls)) # model.predictの引数conf要設定

price=[150,140] #単価 [ponde,old]
quantity=[counter["0"]-1,counter["1"]] #個数 [ponde,old]

print("ポンデリング\t\t:",price[0],"円 x",counter["0"]-1,"個 =",price[0]*quantity[0],"円")
print("オールドファッション\t:",price[1],"円 x",counter["1"],"個 =",price[1]*quantity[1],"円")
print("合計金額\t\t:",price[0]*quantity[0]+price[1]*quantity[1],"円")
# Out:
# ポンデリング		: 150 円 x 2 個 = 300 円
# オールドファッション	: 140 円 x 1 個 = 140 円
# 合計金額		: 440 円
